# %% [markdown]
# # Fits  ([documentation](http://docs.astropy.org/en/stable/io/fits/))

# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load data

# %% [markdown]
# Let's work with the following file

# %%
fits_file = 'Data/Images/test_image.fits'

# %% [markdown]
# Always good to check if our file really exists

# %%
import os
assert os.path.exists(fits_file)

# %% [markdown]
# We open the file and retrieve the data

# %%
file_handle = fits.open(fits_file)
fits_array = file_handle[0].data

# %% [markdown]
# What is the shape of our array

# %%
np.shape(fits_array)
# Out:
# (4096, 4096)

# %% [markdown]
# Let's plot our image

# %%
f1,ax1=plt.subplots(figsize=(5,5))
cax1=ax1.imshow(fits_array)
f1.colorbar(cax1)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Want a better plot?

# %%
# %matplotlib notebook

# %%
f2,ax2=plt.subplots(figsize=(5,5))
cax2=ax2.imshow(fits_array)
f2.colorbar(cax2)
# Out:
# <img src="data:image/png;base64,..." width="520">

# %% [markdown]
# ## metadata

# %%
file_handle[0].header
# Out:
# SIMPLE  =                    T / Created by ImageJ FITS_Writer
# BITPIX  =                  -32 / number of bits per data pixel
# NAXIS   =                    2 / number of data axes
# NAXIS1  =                 4096 / length of data axis 1
# NAXIS2  =                 4096 / length of data axis 2
# BZERO   =                    0 / data range offset
# BSCALE  =                    1 / default scaling factor

# %% [markdown]
# We are done here, so let's close the file!

# %%
file_handle.close()
